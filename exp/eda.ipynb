# %%
import pandas as pd

df = pd.read_csv('dataset/mimic_perform_non_af_csv/mimic_perform_non_af_001_data.csv')
print(f'Testing DataFrame shape: {df.shape}')
# Out:
# Testing DataFrame shape: (150001, 4)

# %%
df
# Out:
#             Time       PPG       ECG      resp
# 0          0.000  0.410557  0.314453  0.717097
# 1          0.008  0.400782  0.285156  0.720787
# 2          0.016  0.391007  0.300781  0.723247
# 3          0.024  0.382209  0.304688  0.726937
# 4          0.032  0.372434  0.294922  0.730627
# ...          ...       ...       ...       ...
# 149996  1199.968  0.258065  0.279297  0.116851
# 149997  1199.976  0.262952  0.275391  0.115621
# 149998  1199.984  0.273705  0.279297  0.114391
# 149999  1199.992  0.290323  0.279297  0.114391
# 150000  1200.000  0.314761  0.285156  0.114391
#
# [150001 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

df[['Time', 'PPG']][:5500].plot(x='Time', y='PPG')
plt.xlabel('Time')
plt.ylabel('PPG')
plt.title('PPG Trends')
plt.show()
